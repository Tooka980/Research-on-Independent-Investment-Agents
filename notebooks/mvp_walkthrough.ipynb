# %% [markdown]
# # Independent Investment Agents MVP Walkthrough
#
# This notebook shows how to inspect the experiment config and read simulation artifacts.

# %%
from pathlib import Path
import json
import pandas as pd

config_path = Path('../configs/experiments/jp_etf_news_mvp.toml')
config_path

# %%
artifacts_root = Path('../artifacts/runs')
runs = sorted(artifacts_root.glob('*'))
runs[-1] if runs else 'Run the CLI first to create artifacts.'
